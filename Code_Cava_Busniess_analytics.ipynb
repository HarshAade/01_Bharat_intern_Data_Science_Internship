# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshAade/01_Bharat_intern_Data_Science_Internship/blob/main/Code_Cava_Busniess_analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01 Task
#
#        Task 01.1 :-  Heading: Data Cleaning and Preprocessing for Amazon's Dataset
#
#        Introduction :- In this project, I am conducting data cleaning and preprocessing on Amazon's dataset to ensure data integrity and prepare it
#        for analysis and decision-making. The goal is to eliminate inconsistencies, handle missing values, and transform the data to enable accurate
#        and reliable business insights.

# %% [markdown]
# ## Features
#
# 1. product_id - Product ID
#
# 2. product_name - Name of the Product
#
# 3. category - Category of the Product
#
# 4. discounted_price - Discounted Price of the Product
#
# 5. actual_price - Actual Price of the Product
#
# 6. discount_percentage - Percentage of Discount for the Product
#
# 7. rating - Rating of the Product
#
# 8. rating_count - Number of people who voted for the Amazon rating
#
# 9. about_product - Description about the Product
#
# 10. user_id - ID of the user who wrote review for the Product
#
# 11. user_name - Name of the user who wrote review for the Product
#
# 12. review_id - ID of the user review
#
# 13. review_title - Short review
#
# 14. review_content - Long review
#
# 15. img_link - Image Link of the Product
#
# 16. product_link - Official Website Link of the Product

# %%
import pandas as pd

# load CSV file from Google Drive
df = pd.read_csv("amazon.csv")

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
# check the number of rows and columns
df.shape
# Out:
# (1465, 16)

# %%
# Check for missing values
def check_missing_values(dataframe):
    return dataframe.isnull().sum()

print(check_missing_values(df))
df[df.rating_count.isnull()]
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category discounted_price  \
# 282  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 324  Computers&Accessories|Accessories&Peripherals|...             ₹249
#
#     actual_price discount_percentage rating rating_count  \
# ...

# %%
# Remove rows with missing values in the rating_count column
df.dropna(subset=['rating_count'], inplace=True)
print(check_missing_values(df))
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
# Check for duplicates
def check_duplicates(dataframe):
    return dataframe.duplicated().sum()

print(check_duplicates(df))
# Out:
# 0

# %%
# Check data types
def check_data_types(dataframe):
    return dataframe.dtypes

print(check_data_types(df))
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %% [markdown]
# Converting Object Data Types to Numeric for Numerical Analysis
#
#        Explanation: In datasets, some variables may be represented as object data types (strings), hindering numerical analysis.
#        For instance, calculating the total price of products is impossible with price data in object format.
#        To facilitate numerical operations, these variables must be converted to numeric data types.

# %%
df['discounted_price'] = df['discounted_price'].astype(str).str.replace('₹', '').str.replace(',', '').astype(float)
df['actual_price'] = df['actual_price'].astype(str).str.replace('₹', '').str.replace(',', '').astype(float)
df['discount_percentage'] = df['discount_percentage'].astype(str).str.replace('%','').astype(float)/100

# %%
# The rating column has a value with an incorrect character, so we will exclude
# the row to obtain a clean dataset.
count = df['rating'].str.contains('\|').sum()
print(f"Total de linhas com '|' na coluna 'rating': {count}")
df = df[df['rating'].apply(lambda x: '|' not in str(x))]
count = df['rating'].str.contains('\|').sum()
print(f"Total de linhas com '|' na coluna 'rating': {count}")
# Out:
# Total de linhas com '|' na coluna 'rating': 1
# Total de linhas com '|' na coluna 'rating': 0

# %%
df['rating'] = df['rating'].astype(str).str.replace(',', '').astype(float)
df['rating_count'] = df['rating_count'].astype(str).str.replace(',', '').astype(float)

# %%
print(check_data_types(df))
# Out:
# product_id              object
# product_name            object
# category                object
# discounted_price       float64
# actual_price           float64
# discount_percentage    float64
# rating                 float64
# rating_count           float64
# about_product           object
# user_id                 object
# user_name               object
# review_id               object
# review_title            object
# review_content          object
# img_link                object
# product_link            object
# dtype: object

# %% [markdown]
# Objective: Adding a "rating_weighted" Column for Better Product Assessment
#
#        Explanation: We're introducing a new column, "rating_weighted," to our database.
#        This column combines the average rating and the number of ratings for each product.
#        It's an easy way to highlight products that not only have high average ratings but also lots of people
#        who've rated them positively, helping us identify the most popular and well-received products.

# %%
# Creating the column "rating_weighted"
df['rating_weighted'] = df['rating'] * df['rating_count']

# %% [markdown]
# **Objective:** Clarifying Product Categories for Better Understanding
#
#        Explanation: We want to extract two types of categories from our "category" column: the main category,
#        which gives a broad idea of the product's type (like "Electronics"),
#        and the final category, which offers specific details (like "Smartphones").
#
#        For example, if we see "Electronics" as the main category and "Smartphones" as the final category,
#        we understand that this product falls under electronics but is specifically a smartphone.
#        This helps us grasp how products are distributed across different categories and spot trends.
#
#        Moreover, extracting these categories makes it easier to create visualizations that show product distribution more clearly.
#
#        In short, extracting both main and final categories is an important part of our data analysis,
#        helping us understand our data better and make more informed decisions.

# %%
df['sub_category'] = df['category'].astype(str).str.split('|').str[-1]
df['main_category'] = df['category'].astype(str).str.split('|').str[0]

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link', 'rating_weighted',
#        'sub_category', 'main_category'],
#       dtype='object')

# %%
len(df)
# Out:
# 1462

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 0.64     4.2       24269.0
# ...

# %% [markdown]
#  EDA and Data Visualization
#
#         3.1 Category Distribution : Analyze product distribution across categories with a bar plot.
#
#         3.2 Rating Distribution : Explore customer ratings through a histogram.
#
#         3.3 Review Analysis : Gain insights from reviews using word clouds or frequency tables.
#
#         3.4 Statistical Analysis : Identify correlations between features, e.g., price vs. ratings.
#
# 🕵️‍♂️ Dive into the data for valuable insights!

# %%
import matplotlib.pyplot as plt

#3.1
# Analyzing distribution of products by main category
main_category_counts = df['main_category'].value_counts()[:30] # Select only the top 30 main categories.
plt.bar(range(len(main_category_counts)), main_category_counts.values)
plt.ylabel('Number of Products')
plt.title('Distribution of Products by Main Category (Top 30)')
plt.xticks(range(len(main_category_counts)), '') # hide X-axis labels
plt.show()

# Top 30 main categories
top_main_categories = pd.DataFrame({'Main Category': main_category_counts.index, 'Number of Products': main_category_counts.values})
print('Top 30 main categories:')
print(top_main_categories.to_string(index=False))
# Out:
# Top 30 main categories:
#         Main Category  Number of Products
#           Electronics                 526
# Computers&Accessories                 451
#          Home&Kitchen                 447
#        OfficeProducts                  31
#    MusicalInstruments                   2
#       HomeImprovement                   2
#            Toys&Games                   1
#         Car&Motorbike                   1
#   Health&PersonalCare                   1

# %% [markdown]
# **Key Insights:**
#
# 🔍 Top 3 Popular Categories: Electronics, Computers & Accessories, and Home & Kitchen are the most favored categories among customers.
#
# 🔍 Less Popular Categories: Other main categories have significantly fewer products, indicating lower popularity.
#
# 🔍 Low Demand Categories: Office Products, Musical Instruments, Home Improvement, Toys & Games, Car & Motorbike, and Health & Personal Care have very few products, suggesting limited demand.
#
# 🔍 Market Trends: This data provides valuable insights into current market trends and potential growth opportunities within specific categories for businesses.

# %%
# Analyzing distribution of products by last category
sub_category_counts = df['sub_category'].value_counts()[:30] # Select only the top 30 last categories.
plt.bar(range(len(sub_category_counts)), sub_category_counts.values)
plt.ylabel('Number of Products')
plt.title('Distribution of Products by Sub Category (Top 30)')
plt.xticks(range(len(sub_category_counts)), '') # hide X-axis labels
plt.show()

# Top 30 sub categories
top_sub_categories = pd.DataFrame({'Sub Category': sub_category_counts.index, 'Number of Products': sub_category_counts.values})
print('Top 30 sub categories:')
print(top_sub_categories.to_string(index=False))
# Out:
# Top 30 sub categories:
#             Sub Category  Number of Products
#                USBCables                 231
#             SmartWatches                  76
#              Smartphones                  68
#         SmartTelevisions                  63
#                   In-Ear                  52
#           RemoteControls                  49
#            MixerGrinders                  27
#               HDMICables                  24
#                 DryIrons                  24
#                     Mice                  24
#      InstantWaterHeaters                  23
#              LintShavers                  22
#               FanHeaters                  20
#          ElectricHeaters                  20
#          ElectricKettles                  19
#             HandBlenders                  19
#      WirelessUSBAdapters                  18
#             WallChargers                  16
#                 Lapdesks                  14
# ...

# %% [markdown]
# **Key Subcategory Insights:**
#
# 🔍 Top 6 Popular Subcategories: USB cables, smartwatches, smartphones, smart televisions, in-ear headphones, and remote controls are customer favorites, making them prime areas for businesses to target.
#
# 🔍 Other Demand Subcategories: Mixer grinders, HDMI cables, dry irons, mice, and instant water heaters, while not in the top tier, still have significant demand.
#
# 🔍 Diverse Product Range: The top 30 subcategories span kitchen appliances, home electronics, and personal accessories, emphasizing the importance of offering a diverse product range to meet various customer needs.
#
# 🔍 Business Strategy: Utilizing this data, businesses can align their product offerings with customer demand by focusing on popular subcategories to boost sales and market competitiveness.

# %%
# 3.2 Analyze the distribution of customer ratings using a histogram.
# Plot histogram
plt.hist(df['rating'])
plt.xlabel('Rating')
plt.ylabel('Number of Reviews')
plt.title('Distribution of Customer Ratings')
plt.show()

# Create table with values per cluster
bins = [0, 1, 2, 3, 4, 5] # Define bin edges
df['cluster'] = pd.cut(df['rating'], bins=bins, include_lowest=True, labels=['0-1', '1-2', '2-3', '3-4', '4-5'])
table = df['cluster'].value_counts().reset_index().sort_values('index').rename(columns={'index': 'Cluster', 'cluster': 'Number of Reviews'})
print(table)
# Out:
#   Cluster  Number of Reviews
# 4     0-1                  0
# 3     1-2                  1
# 2     2-3                  8
# 1     3-4                525
# 0     4-5                928

# %% [markdown]
# **Customer Rating Insights:**
#
# 📊 Most Ratings in 3-4 and 4-5 Range: The majority of reviews fall within the 3-4 and 4-5 rating ranges, totaling 1453 reviews.
#
# 📈 Increase in 2-3 Range: More reviews are in the 2-3 range compared to the lower 0-1 and 1-2 ranges.
#
# 👎 Fewest Reviews in 0-1 Range: The lowest number of reviews is in the 0-1 range, indicating potential for improvement in customer satisfaction.
#
# 🤔 Overall, ratings distribution shows most customers are satisfied, but there's room to enhance the number of positive ratings.

# %%
# Calculate the top main categories
top = df.groupby(['main_category'])['rating'].mean().sort_values(ascending=False).head(10).reset_index()

# Create a bar plot
plt.bar(top['main_category'], top['rating'])

# Add labels and title
plt.xlabel('main_category')
plt.ylabel('Rating')
plt.title('Top main_category by Rating')

# Rotate x-axis labels
plt.xticks(rotation=90)

# Show the plot
plt.show()
ranking = df.groupby('main_category')['rating'].mean().sort_values(ascending=False).reset_index()
print(ranking)
# Out:
#            main_category    rating
# 0         OfficeProducts  4.309677
# 1             Toys&Games  4.300000
# 2        HomeImprovement  4.250000
# 3  Computers&Accessories  4.155654
# 4            Electronics  4.081749
# 5           Home&Kitchen  4.040716
# 6    Health&PersonalCare  4.000000
# 7     MusicalInstruments  3.900000
# 8          Car&Motorbike  3.800000

# %% [markdown]
# **Main Category Rating Insights:**
#
# 📊 Top-Rated Main Categories: Office Products, Toys & Games, and Home Improvement lead with ratings above 4.0, indicating high customer satisfaction.
#
# 💻 Lower-Rated Main Categories: Car & Motorbike, Musical Instruments, and Health & Personal Care have ratings below 4.0, suggesting areas for potential improvement.
#
# 👨‍💻 Popular Categories: Computers & Accessories and Electronics boast ratings above 4.0, signifying their popularity and customer satisfaction.
#
# 👍 Overall, this table offers valuable insights into main category performance, guiding businesses in enhancing their offerings and customer satisfaction.

# %%
# Calculate the top sub categories
top = df.groupby(['sub_category'])['rating'].mean().sort_values(ascending=False).head(10).reset_index()

# Create a bar plot
plt.bar(top['sub_category'], top['rating'])

# Add labels and title
plt.xlabel('sub_category')
plt.ylabel('Rating')
plt.title('Top sub_category by Rating')

# Rotate x-axis labels
plt.xticks(rotation=90)

# Show the plot
plt.show()
ranking = df.groupby('sub_category')['rating'].mean().sort_values(ascending=False).reset_index()
print(ranking)
# Out:
#                         sub_category  rating
# 0                            Tablets     4.6
# 1                               Film     4.5
# 2                             Memory     4.5
# 3    SmallApplianceParts&Accessories     4.5
# 4                   StreamingClients     4.5
# ..                               ...     ...
# 202                   InkjetPrinters     3.6
# 203                       PCHeadsets     3.5
# 204                        3DGlasses     3.5
# 205                       DustCovers     3.4
# 206                 ElectricGrinders     3.3
#
# [207 rows x 2 columns]

# %% [markdown]
# **Subcategory Rating Insights:**
#
# 📊 Top and Bottom Subcategories: This table highlights the highest and lowest-rated subcategories based on customer ratings.
#
# 👍 Top Performer: "Tablets" leads with an impressive rating of 4.6, indicating high customer satisfaction.
#
# 📉 Areas for Improvement: Subcategories like "DustCovers" and "ElectricGrinders" have lower ratings, suggesting room for improvement in customer satisfaction.
#
# 💡 Valuable Business Insights: These insights are invaluable for businesses, offering an opportunity to enhance product quality and the overall customer experience. Continuous monitoring of customer feedback is essential to identify areas for improvement and meet customer expectations.

# %%
# sort the means in descending order
mean_discount_by_category = df.groupby('main_category')['discount_percentage'].mean()
mean_discount_by_category = mean_discount_by_category.sort_values(ascending=True)

# create the horizontal bar chart
plt.barh(mean_discount_by_category.index, mean_discount_by_category.values)
plt.title('Discount Percentage by Main Category')
plt.xlabel('Discount Percentage')
plt.ylabel('Main Category')
plt.show()

table = pd.DataFrame({'Main Category': mean_discount_by_category.index, 'Mean Discount Percentage': mean_discount_by_category.values})

print(table)
# Out:
#            Main Category  Mean Discount Percentage
# 0             Toys&Games                  0.000000
# 1         OfficeProducts                  0.123548
# 2           Home&Kitchen                  0.401745
# 3          Car&Motorbike                  0.420000
# 4     MusicalInstruments                  0.460000
# 5            Electronics                  0.508289
# 6    Health&PersonalCare                  0.530000
# 7  Computers&Accessories                  0.539202
# 8        HomeImprovement                  0.575000

# %% [markdown]
# **Main Category Discount Insights:**
#
# 📊 Discount Percentages by Main Category: The table displays the mean discount percentages, sorted in descending order.
#
# 🧸 Lowest Discounts: "Toys & Games" has the lowest mean discount percentage at 0.0. This suggests that toys and games enjoy high demand without requiring significant discounts.
#
# 🏠 Similar Discounts: "Home & Kitchen" and "Car & Motorbike" have similar mean discount percentages (0.401745 and 0.42), indicating a comparable level of competition and price sensitivity.
#
# 🎼 Highest Discounts: "Home Improvement," "Computers & Accessories," and "Electronics" have the highest mean discount percentages (0.575, 0.539202, and 0.508289), suggesting higher price sensitivity and the need for attractive discounts.
#
# 💻 Interesting Findings: "Office Products" and "Health & Personal Care" fall in between, with mean discount percentages (0.123548 and 0.53) indicating moderate price sensitivity compared to other categories.
#
# 🤔 These insights can help businesses tailor their pricing and discount strategies to meet the varying demands and price sensitivities of different main categories.

# %%
# sort the means in descending order
mean_discount_by_sub_category = df.groupby('sub_category')['discount_percentage'].mean().head(15)
mean_discount_by_sub_category = mean_discount_by_sub_category.sort_values(ascending=True)

# create the horizontal bar chart
plt.barh(mean_discount_by_sub_category.index, mean_discount_by_sub_category.values)
plt.title('Discount Percentage by Sub Category')
plt.xlabel('Discount Percentage')
plt.ylabel('Sub Category')
plt.show()

table = pd.DataFrame({'Sub Category': mean_discount_by_sub_category.index, 'Mean Discount Percentage': mean_discount_by_sub_category.values})

print(table)
# Out:
#               Sub Category  Mean Discount Percentage
# 0                    Basic                  0.000000
# 1             BasicMobiles                  0.185556
# 2                3DGlasses                  0.230000
# 3          BatteryChargers                  0.250000
# 4        BluetoothAdapters                  0.330000
# 5   AVReceivers&Amplifiers                  0.360000
# 6    AirPurifiers&Ionizers                  0.420000
# 7                AirFryers                  0.440000
# 8       BackgroundSupports                  0.460000
# 9        BluetoothSpeakers                  0.485000
# 10  Adapters&Multi-Outlets                  0.570000
# 11      AutomobileChargers                  0.580000
# 12              BasicCases                  0.707500
# 13     Bedstand&DeskMounts                  0.745000
# 14                Adapters                  0.803333

# %% [markdown]
# **Subcategory Discount Insights:**
#
# 📊 Mean Discount Percentages by Subcategory: The table displays mean discount percentages, sorted in descending order.
#
# 📱 Lowest Discounts: "Basic" subcategory has the lowest mean discount percentage at 0.0, suggesting that basic and low-cost products don't require heavy discounts.
#
# 🔋 Moderate Discounts: Subcategories like "Battery Chargers," "3D Glasses," and "Basic Mobiles" have moderate mean discount percentages (0.18 to 0.25), indicating some price sensitivity but not extreme.
#
# 🎧 High Discounts: "Bluetooth Speakers," "Bedstand & Desk Mounts," and "Basic Cases" have high mean discount percentages (0.485 to 0.745), suggesting greater price sensitivity and the need for competitive discounts.
#
# 🔌 Highest Discounts: "Adapters" tops the list with the highest mean discount percentage at 0.803333, indicating intense competition and the necessity for substantial discounts.
#
# 👨‍💻 Overall, this table emphasizes the variation in mean discount percentages among subcategories. Retailers should tailor pricing and discount strategies for each subcategory to effectively compete in the market.

# %%
from wordcloud import WordCloud

# 3.3 Analyze the reviews by creating word clouds or frequency tables of the most common words used in the reviews.
reviews_text = ' '.join(df['review_content'].dropna().values)
wordcloud = WordCloud(width=800, height=800, background_color='white', min_font_size=10).generate(reviews_text)
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# 📊👀 Word Cloud for High-Rated Products
#
# 🔍 This code generates a word cloud using the reviews text from the dataset, making it easy to visually identify the most frequently used words. Words appearing larger in the cloud are mentioned more often in the reviews.
#
# 💬 Insights Galore: It offers insights into customer sentiment, frequently mentioned product features, and issues. Businesses can use this information to enhance their products and services.
#
# 🌟 In this example, the word cloud focuses on products with ratings greater than 4, highlighting positive feedback and valuable insights.

# %%
# Filter the dataframe to include only products with a rating lower than 2
low_rating_df = df[df['rating'] > 4.0]

# Create a string of all the reviews for these products
reviews_text = ' '.join(low_rating_df['review_content'].dropna().values)

# Generate the wordcloud
wordcloud = WordCloud(width=800, height=800, background_color='white', min_font_size=10).generate(reviews_text)

# Plot the wordcloud
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
# 3.4 Perform statistical analysis to identify any correlations between different features, such as the relationship between product price and customer rating.
# Drop non-numeric columns
numeric_cols = df.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_cols.corr()

# Print the correlation matrix
print(correlation_matrix)
# Out:
#                      discounted_price  actual_price  discount_percentage  \
# discounted_price             1.000000      0.961910            -0.242298
# actual_price                 0.961910      1.000000            -0.117855
# discount_percentage         -0.242298     -0.117855             1.000000
# rating                       0.121132      0.122467            -0.155679
# rating_count                -0.027304     -0.036215             0.011294
# rating_weighted             -0.027039     -0.035959             0.010701
#
#                        rating  rating_count  rating_weighted
# discounted_price     0.121132     -0.027304        -0.027039
# actual_price         0.122467     -0.036215        -0.035959
# discount_percentage -0.155679      0.011294         0.010701
# rating               1.000000      0.102235         0.115217
# rating_count         0.102235      1.000000         0.999061
# rating_weighted      0.115217      0.999061         1.000000

# %%
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# **Correlation Insights:**
#
# 📊 Correlation Table: Presented is a correlation table displaying relationships between various dataset variables.
#
# 🌟 Weak Positive Correlation: The overall rating shows a weak positive correlation with both rating count and weighted rating. This suggests that products with higher ratings tend to have more reviews and higher weighted ratings.
#
# 🌟 Moderate Positive Correlation: A moderate positive correlation (0.121) exists between "rating" and "discounted_price," implying that customers may give higher ratings to discounted products.
#
# 📈 Correlation vs. Causation: It's essential to remember that correlation does not imply causation. These insights help us understand data relationships.
#
# 📉 Interpretation Guidelines: Correlation strength interpretation can vary but, as a rule of thumb, a coefficient (r) between 0.1 and 0.3 is weak, between 0.3 and 0.5 is moderate, and above 0.5 is strong. Factors like sample size and outliers should also be considered.
#
# 🌟 Keep exploring for valuable insights!

# %% [markdown]
# **4. Recommendation System**
#
# 👋 Hello there! As a data scientist, our goal is to enhance users' product discovery experience. To achieve this, we're developing a recommendation system using Amazon's dataset, which contains valuable information about products, reviews, and users.
#
# 📊 Dataset Overview: The dataset comprises 1462 rows with columns like 'product_name,' 'category,' 'discounted_price,' 'actual_price,' and more.
#
# 🤝 Personalized Recommendations: Our aim is to create a personalized recommendation system. When users log in, they'll receive product suggestions tailored to their interests and past interactions with our platform. This means they'll discover new and exciting products that align with their preferences, making their shopping journey enjoyable and hassle-free. 🤩
#
# Stay tuned for more exciting developments!

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['user_id_encoded'] = le.fit_transform(df['user_id'])

# Create a new dataframe with the user_id frequency table
freq_table = pd.DataFrame({'User ID': df['user_id_encoded'].value_counts().index, 'Frequency': df['user_id_encoded'].value_counts().values})

# Display the dataframe
print(freq_table)
id_example = freq_table.iloc[0,0]
print(id_example)
# Out:
#       User ID  Frequency
# 0        1045         10
# 1         622          8
# 2         673          8
# 3         253          7
# 4          87          7
# ...       ...        ...
# 1186      505          1
# 1187       11          1
# 1188      897          1
# 1189      369          1
# 1190      432          1
#
# [1191 rows x 2 columns]
# 1045

# %% [markdown]
# **Converting Strings to Numbers in Data Analysis and ML**
#
# 😃 Converting strings to numbers is a common step with multiple benefits:
#
# 👨‍💻 **Algorithm Compatibility:** Many ML algorithms require numeric data, ensuring proper processing of data.
#
# 📊 **Ease of Handling:** Numeric data is easier for calculations, making it useful for statistics and operations.
#
# 🚀 **Recommendation Systems:** Converting user IDs from strings to numbers simplifies similarity score calculations, enhancing recommendation system efficiency and accuracy.
#
# 🤖 Overall, this conversion is a valuable practice in data analysis and ML, particularly for optimizing recommendation systems.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def recommend_products(df, user_id_encoded):
    # Use TfidfVectorizer to transform the product descriptions into numerical feature vectors
    tfidf = TfidfVectorizer(stop_words='english')
    df['about_product'] = df['about_product'].fillna('')  # fill NaN values with empty string
    tfidf_matrix = tfidf.fit_transform(df['about_product'])

    # Get the purchase history for the user
    user_history = df[df['user_id_encoded'] == user_id_encoded]

    # Use cosine_similarity to calculate the similarity between each pair of product descriptions
    # only for the products that the user has already purchased
    indices = user_history.index.tolist()

    if indices:
        # Create a new similarity matrix with only the rows and columns for the purchased products
        cosine_sim_user = cosine_similarity(tfidf_matrix[indices], tfidf_matrix)

        # Create a pandas Series with product indices as the index and product names as the values
        products = df.iloc[indices]['product_name']
        indices = pd.Series(products.index, index=products)

        # Get the indices and similarity scores of products similar to the ones the user has already purchased
        similarity_scores = list(enumerate(cosine_sim_user[-1]))
        similarity_scores = [(i, score) for (i, score) in similarity_scores if i not in indices]

        # Sort the similarity scores in descending order
        similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)

        # Get the indices of the top 5 most similar products
        top_products = [i[0] for i in similarity_scores[1:6]]

        # Get the names of the top 5 most similar products
        recommended_products = df.iloc[top_products]['product_name'].tolist()

        # Get the reasons for the recommendation
        score = [similarity_scores[i][1] for i in range(5)]

        # Create a DataFrame with the results
        results_df = pd.DataFrame({'Id Encoded': [user_id_encoded] * 5,
                                   'recommended product': recommended_products,
                                   'score recommendation': score})

        return results_df

    else:
        print("No purchase history found.")
        return None

# %%
recommend_products(df, 893)
# Out:
#    Id Encoded                                recommended product  \
# 0         893  FYA Handheld Vacuum Cleaner Cordless, Wireless...
# 1         893  Eureka Forbes Active Clean 700 Watts Powerful ...
# 2         893  AMERICAN MICRONIC- Imported Wet & Dry Vacuum C...
# 3         893  INALSA Upright Vacuum Cleaner, 2-in-1,Handheld...
# 4         893  INALSA Vaccum Cleaner Handheld 800W High Power...
#
#    score recommendation
# 0              1.000000
# 1              0.347227
# 2              0.317435
# 3              0.310397
# 4              0.298666

# %% [markdown]
# **🛍️💻 Simple Recommendation System Insights:**
#
# 🧐👨‍💻 **Understanding Customer Preferences:** By analyzing user purchases, we unveil attractive categories and features, guiding optimized product design and targeted marketing.
#
# 👉 **Increasing Customer Engagement:** Tailored product suggestions enhance user engagement and satisfaction, fostering retention and loyalty.
#
# 💼 **Improving Sales:** Recommending similar or complementary products boosts cross-selling and up-selling opportunities, resulting in increased revenue and profitability.
#
# 💡 **Overall Impact:** Our Simple Recommendation System equips companies to comprehend customers better, elevate engagement and satisfaction, and drive sales growth.

# %% [markdown]
# # 02 Task
